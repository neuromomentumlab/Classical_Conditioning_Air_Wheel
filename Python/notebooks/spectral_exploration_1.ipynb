# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path

from src.proc.whole_session_spectral_batch import (
    WholeSessionSpectralConfig,
    build_whole_session_spectral_tables,
    save_whole_session_spectral_tables,
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 6
#       2 get_ipython().run_line_magic('autoreload', '2')
#       4 from pathlib import Path
# ----> 6 from src.proc.whole_session_spectral_batch import (
#       7     WholeSessionSpectralConfig,
#       8     build_whole_session_spectral_tables,
#       9     save_whole_session_spectral_tables,
#      10 )
#
# ModuleNotFoundError: No module named 'src'
